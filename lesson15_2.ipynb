# %%
import numpy as np
import pandas as pd

scores = np.random.randint(40,high=101,size=(50,5))
scores_df=pd.DataFrame(scores,
    columns=['國文','英文','數學','地理','歷史'],
    index=range(1,51))
scores_df.index.name="學號"
scores_df.columns.name="科目"

#display(sum_series)               #sum總分 #mean平均 #rank排名
sum_series=scores_df.sum(axis=1)
mean_series=scores_df.mean(axis=1)
rank_series=sum_series.rank(method='min',ascending=False) #rank依照總分1~50(但表格整體排列沒有變)
scores_df['總分']=sum_series
scores_df['平均']=mean_series
scores_df['名次']=rank_series
scores_df.sort_values(by="名次")   #sort_value把表格依照名次排列
# Out:
# 科目  國文  英文   數學   地理   歷史   總分    平均    名次
# 學號
# 38  94  98  100   61   96  449  89.8   1.0
# 46  97  92   97   81   76  443  88.6   2.0
# 34  82  75   92  100   81  430  86.0   3.0
# 30  60  76   99   89   89  413  82.6   4.0
# 23  77  78   86   92   74  407  81.4   5.0
# 12  79  71   73   78   94  395  79.0   6.0
# 25  93  94   82   51   72  392  78.4   7.0
# 2   71  94   46   99   80  390  78.0   8.0
# 4   49  84   75  100   76  384  76.8   9.0
# 3   86  75   59   64   98  382  76.4  10.0
# 6   93  70   74   57   88  382  76.4  10.0
# 31  79  49   89  100   60  377  75.4  12.0
# 24  63  41   88   90   94  376  75.2  13.0
# 20  40  93   91   85   67  376  75.2  13.0
# 9   72  83   87   90   43  375  75.0  15.0
# 19  83  99   94   43   53  372  74.4  16.0
# 50  96  98   50   60   67  371  74.2  17.0
# 18  87  51   87   97   43  365  73.0  18.0
# 7   78  72   75   57   74  356  71.2  19.0
# 32  86  71   73   42   83  355  71.0  20.0
# 42  76  63   53   67   95  354  70.8  21.0
# 41  82  49   88   71   64  354  70.8  21.0
# 5   58  73   45   93   82  351  70.2  23.0
# 27  43  88   97   52   64  344  68.8  24.0
# 26  45  89   44   74   91  343  68.6  25.0
# 35  96  56   72   61   56  341  68.2  26.0
# 10  49  55   97   58   80  339  67.8  27.0
# 47  55  41   69   97   72  334  66.8  28.0
# 13  50  74   87   57   66  334  66.8  28.0
# 21  66  88   79   48   51  332  66.4  30.0
# 22  69  80   42   75   64  330  66.0  31.0
# 28  63  53  100   62   51  329  65.8  32.0
# 37  74  40   63   84   67  328  65.6  33.0
# 1   77  96   43   55   52  323  64.6  34.0
# 14  61  63   45   51  100  320  64.0  35.0
# 11  92  55   41   59   70  317  63.4  36.0
# 45  67  71   57   73   46  314  62.8  37.0
# 48  69  85   76   42   42  314  62.8  37.0
# 33  41  69   65   40   93  308  61.6  39.0
# 40  83  42   62   78   43  308  61.6  39.0
# 39  44  64   73   85   41  307  61.4  41.0
# 43  52  62   63   58   72  307  61.4  41.0
# 44  42  81   88   54   41  306  61.2  43.0
# 17  54  63   44   52   92  305  61.0  44.0
# 15  44  57   59   69   71  300  60.0  45.0
# 36  76  40   51   77   46  290  58.0  46.0
# 8   75  52   50   46   67  290  58.0  46.0
# 16  80  50   70   46   41  287  57.4  48.0
# 49  44  57   74   55   47  277  55.4  49.0
# 29  75  41   44   60   46  266  53.2  50.0
